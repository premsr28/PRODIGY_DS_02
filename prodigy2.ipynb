# %%
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("gender_submission.csv")

# %%
df.isnull().sum()
df.info()

# %%
df=pd.DataFrame(df)
f=df.head(20)
plt.bar(f['PassengerId'],f['Survived'])
plt.show()

# %%
df['Survived'].hist()
# Out:
# <Axes: >

# %%
df['Survived']=df['Survived'].replace({0:'death',1:'survived'})
df.head()
# Out:
#    PassengerId  Survived
# 0          892     death
# 1          893  survived
# 2          894     death
# 3          895     death
# 4          896  survived

# %%
h=df['Survived'].value_counts()
h
# Out:
# Survived
# death       266
# survived    152
# Name: count, dtype: int64

# %%
h=h.plot(kind='bar')
